# %%
import sys
sys.path.append("path/to/SWSNet/repo")

# %%
from simulation_2layer import generate_deconvolved
import numpy as np
from math import pi, tan, atan

# %%
### set of splitting parameters:

phi1 = 20
phi2 = 110
dt1 = 1.5
dt2 = 0.5

# %%
BAZ = 60

alpha11 = BAZ-phi1
alpha12 = BAZ-phi2

nlevel = np.random.normal(0.3,0.1)

synth = generate_deconvolved(alpha11, dt1, alpha12, dt2, tsign = -1, 
                             nlevel = nlevel, period = 10, wlevel = 1e-6, make_plots=True)
