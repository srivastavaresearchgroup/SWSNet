# %%
import sys
sys.path.append("path/to/SWSNet/repo")

# %%
from simulation import generate_deconvolved
import numpy as np
from math import pi, tan, atan

# %%
deltat = 1.0 ## time difference in seconds
alpha = 120 ### difference between BAZ and phi in degrees

# %%
nlevel = np.random.normal(0.3,0.1)
synth = generate_deconvolved(alpha, deltat, nlevel = nlevel, wlevel = 1e-6, make_plots=True)
